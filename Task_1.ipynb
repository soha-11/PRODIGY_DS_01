# %%
#Task-1
#Create a Bar Chart or Histogram to visualize the distribution of a categorical variable,such
#as the distribution of ages or genders in a popluation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import io

# %%
df=pd.read_csv('/content/world_population.csv', skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# 0      58782.0  ...     103594.0     104257.0     104874.0     105439.0
# 1  149742351.0  ...  583651101.0  600008424.0  616377605.0  632746570.0
# 2    9565147.0  ...   32716210.0   33753499.0   34636207.0   35643418.0
# 3  108336203.0  ...  397855507.0  408690375.0  419778384.0  431138704.0
# 4    5736582.0  ...   27128337.0   28127721.0   29154746.0   30208628.0
#
#           2018         2019         2020         2021         2022  2023
# 0     105962.0     106442.0     106585.0     106537.0     106445.0   NaN
# 1  649757148.0  667242986.0  685112979.0  702977106.0  720859132.0   NaN
# 2   36686784.0   37769499.0   38972230.0   40099462.0   41128771.0   NaN
# 3  442646825.0  454306063.0  466189102.0  478185907.0  490330870.0   NaN
# 4   31273533.0   32353588.0   33428486.0   34503774.0   35588987.0   NaN
#
# [5 rows x 68 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# 1      SP.POP.TOTL  130692579.0  134169237.0  137835590.0  141630546.0
# 2      SP.POP.TOTL    8622466.0    8790140.0    8969047.0    9157465.0
# 3      SP.POP.TOTL   97256290.0   99314028.0  101445032.0  103667517.0
# 4      SP.POP.TOTL    5357195.0    5441333.0    5521400.0    5599827.0
# ..             ...          ...          ...          ...          ...
# 261    SP.POP.TOTL     947000.0     966000.0     994000.0    1022000.0
# 262    SP.POP.TOTL    5542459.0    5646668.0    5753386.0    5860197.0
# 263    SP.POP.TOTL   16520441.0   16989464.0   17503133.0   18042215.0
# 264    SP.POP.TOTL    3119430.0    3219451.0    3323427.0    3431381.0
# 265    SP.POP.TOTL    3806310.0    3925952.0    4049778.0    4177931.0
#
#             1964         1965  ...         2014         2015         2016  \
# 0        58178.0      58782.0  ...     103594.0     104257.0     104874.0
# 1    145605995.0  149742351.0  ...  583651101.0  600008424.0  616377605.0
# 2      9355514.0    9565147.0  ...   32716210.0   33753499.0   34636207.0
# 3    105959979.0  108336203.0  ...  397855507.0  408690375.0  419778384.0
# 4      5673199.0    5736582.0  ...   27128337.0   28127721.0   29154746.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1050000.0    1078000.0  ...    1812771.0    1788196.0    1777557.0
# 262    5973803.0    6097298.0  ...   27753304.0   28516545.0   29274002.0
# 263   18603097.0   19187194.0  ...   54729551.0   55876504.0   56422274.0
# 264    3542764.0    3658024.0  ...   15737793.0   16248230.0   16767761.0
# 265    4310332.0    4447149.0  ...   13855753.0   14154937.0   14452704.0
#
#             2017         2018         2019         2020         2021  \
# 0       105439.0     105962.0     106442.0     106585.0     106537.0
# 1    632746570.0  649757148.0  667242986.0  685112979.0  702977106.0
# 2     35643418.0   36686784.0   37769499.0   38972230.0   40099462.0
# 3    431138704.0  442646825.0  454306063.0  466189102.0  478185907.0
# 4     30208628.0   31273533.0   32353588.0   33428486.0   34503774.0
# ..           ...          ...          ...          ...          ...
# 261    1791003.0    1797085.0    1788878.0    1790133.0    1786038.0
# 262   30034389.0   30790513.0   31546691.0   32284046.0   32981641.0
# 263   56641209.0   57339635.0   58087055.0   58801927.0   59392255.0
# 264   17298054.0   17835893.0   18380477.0   18927715.0   19473125.0
# 265   14751101.0   15052184.0   15354608.0   15669666.0   15993524.0
#
#             2022  2023
# 0       106445.0   NaN
# 1    720859132.0   NaN
# 2     41128771.0   NaN
# 3    490330870.0   NaN
# 4     35588987.0   NaN
# ..           ...   ...
# 261    1761985.0   NaN
# 262   33696614.0   NaN
# 263   59893885.0   NaN
# 264   20017675.0   NaN
# 265   16320537.0   NaN
#
# [266 rows x 68 columns]>

# %%
df.shape
# Out:
# (266, 68)

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172860e+08  1.188956e+08  1.210661e+08  1.237484e+08  1.264530e+08
# std    3.695500e+08  3.740958e+08  3.808121e+08  3.895098e+08  3.982497e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291965e+08  1.320558e+08  1.349134e+08  1.378513e+08  1.408944e+08
# std    4.071209e+08  4.164559e+08  4.257477e+08  4.353270e+08  4.452978e+08
# min    4.161000e+03  4.531000e+03  4.930000e+03  5.354000e+03  5.646000e+03
# 25%    5.651150e+05  5.691470e+05  5.773872e+05  5.832700e+05  5.875942e+05
# 50%    4.277636e+06  4.331825e+06  4.385700e+06  4.450934e+06  4.530800e+06
# 75%    3.084892e+07  3.163010e+07  3.209247e+07  3.249927e+07  3.277149e+07
# max    3.328209e+09  3.398480e+09  3.468371e+09  3.540164e+09  3.614573e+09
#
#        ...          2014          2015          2016          2017  \
# count  ...  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   ...  2.966485e+08  3.004946e+08  3.043392e+08  3.081897e+08
# std    ...  9.300107e+08  9.412509e+08  9.524225e+08  9.636026e+08
# min    ...  1.089900e+04  1.087700e+04  1.085200e+04  1.082800e+04
# 25%    ...  1.743309e+06  1.788196e+06  1.777557e+06  1.791003e+06
# 50%    ...  1.028212e+07  1.035808e+07  1.032545e+07  1.030030e+07
# 75%    ...  6.078914e+07  6.073058e+07  6.062750e+07  6.053671e+07
# max    ...  7.317040e+09  7.403850e+09  7.490415e+09  7.576442e+09
#
#                2018          2019          2020          2021          2022  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   3.119766e+08  3.156825e+08  3.192718e+08  3.225338e+08  3.254849e+08
# std    9.744868e+08  9.850388e+08  9.951207e+08  1.004223e+09  1.012161e+09
# min    1.086500e+04  1.095600e+04  1.106900e+04  1.120400e+04  1.131200e+04
# 25%    1.797085e+06  1.788878e+06  1.790133e+06  1.786038e+06  1.761985e+06
# 50%    1.039533e+07  1.044767e+07  1.060623e+07  1.050577e+07  1.048694e+07
# 75%    6.042176e+07  5.987258e+07  6.170452e+07  6.358833e+07  6.549775e+07
# max    7.660371e+09  7.741775e+09  7.820206e+09  7.888306e+09  7.950947e+09
#
#        2023
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN
#
# [8 rows x 64 columns]

# %%
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2019                1
# 2020                1
# 2021                1
# 2022                1
# 2023              266
# Length: 68, dtype: int64

# %%
df.sample()
# Out:
#                                      Country Name Country Code  \
# 64  Europe & Central Asia (excluding high income)          ECA
#
#        Indicator Name Indicator Code         1960         1961         1962  \
# 64  Population, total    SP.POP.TOTL  255726092.0  259951519.0  264183560.0
#
#            1963         1964         1965  ...         2014         2015  \
# 64  268409373.0  272634858.0  276765568.0  ...  387912182.0  390267733.0
#
#            2016         2017         2018         2019         2020  \
# 64  392579664.0  394705361.0  396674671.0  398690076.0  400061023.0
#
#            2021         2022  2023
# 64  401682855.0  397824705.0   NaN
#
# [1 rows x 68 columns]

# %%
total_population=df[df['Indicator Code']=='SP.POP.TOTL']
total_population.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# 0      58782.0  ...     103594.0     104257.0     104874.0     105439.0
# 1  149742351.0  ...  583651101.0  600008424.0  616377605.0  632746570.0
# 2    9565147.0  ...   32716210.0   33753499.0   34636207.0   35643418.0
# 3  108336203.0  ...  397855507.0  408690375.0  419778384.0  431138704.0
# 4    5736582.0  ...   27128337.0   28127721.0   29154746.0   30208628.0
#
#           2018         2019         2020         2021         2022  2023
# 0     105962.0     106442.0     106585.0     106537.0     106445.0   NaN
# 1  649757148.0  667242986.0  685112979.0  702977106.0  720859132.0   NaN
# 2   36686784.0   37769499.0   38972230.0   40099462.0   41128771.0   NaN
# 3  442646825.0  454306063.0  466189102.0  478185907.0  490330870.0   NaN
# 4   31273533.0   32353588.0   33428486.0   34503774.0   35588987.0   NaN
#
# [5 rows x 68 columns]

# %%
total_population_sort=total_population.sort_values(by='2022',ascending=False)
total_population_sort
# Out:
#                Country Name Country Code     Indicator Name Indicator Code  \
# 259                   World          WLD  Population, total    SP.POP.TOTL
# 103        IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 140     Low & middle income          LMY  Population, total    SP.POP.TOTL
# 156           Middle income          MIC  Population, total    SP.POP.TOTL
# 102               IBRD only          IBD  Population, total    SP.POP.TOTL
# ..                      ...          ...                ...            ...
# 255  British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 188                   Palau          PLW  Population, total    SP.POP.TOTL
# 179                   Nauru          NRU  Population, total    SP.POP.TOTL
# 245                  Tuvalu          TUV  Population, total    SP.POP.TOTL
# 110          Not classified          INX  Population, total    SP.POP.TOTL
#
#              1960          1961          1962          1963          1964  \
# 259  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
# 103  2.297972e+09  2.329504e+09  2.374276e+09  2.431314e+09  2.488809e+09
# 140  2.243179e+09  2.274050e+09  2.318173e+09  2.374537e+09  2.431355e+09
# 156  2.107416e+09  2.135116e+09  2.175940e+09  2.228877e+09  2.282094e+09
# 102  1.904347e+09  1.926043e+09  1.960606e+09  2.007061e+09  2.053555e+09
# ..            ...           ...           ...           ...           ...
# 255  7.850000e+03  7.885000e+03  7.902000e+03  7.919000e+03  7.949000e+03
# 188  9.446000e+03  9.639000e+03  9.851000e+03  1.007600e+04  1.031800e+04
# 179  4.582000e+03  4.753000e+03  4.950000e+03  5.198000e+03  5.484000e+03
# 245  5.404000e+03  5.436000e+03  5.471000e+03  5.503000e+03  5.525000e+03
# 110           NaN           NaN           NaN           NaN           NaN
#
#              1965  ...          2014          2015          2016  \
# 259  3.328209e+09  ...  7.317040e+09  7.403850e+09  7.490415e+09
# 103  2.547220e+09  ...  6.160290e+09  6.240231e+09  6.319805e+09
# 140  2.489219e+09  ...  6.081161e+09  6.160876e+09  6.240319e+09
# 156  2.336193e+09  ...  5.513458e+09  5.578703e+09  5.642636e+09
# 102  2.100537e+09  ...  4.616585e+09  4.663653e+09  4.709004e+09
# ..            ...  ...           ...           ...           ...
# 255  8.018000e+03  ...  2.897100e+04  2.936600e+04  2.973900e+04
# 188  1.056300e+04  ...  1.779600e+04  1.779400e+04  1.781600e+04
# 179  5.804000e+03  ...  1.094000e+04  1.118500e+04  1.143700e+04
# 245  5.548000e+03  ...  1.089900e+04  1.087700e+04  1.085200e+04
# 110           NaN  ...           NaN           NaN           NaN
#
#              2017          2018          2019          2020          2021  \
# 259  7.576442e+09  7.660371e+09  7.741775e+09  7.820206e+09  7.888306e+09
# 103  6.399653e+09  6.477695e+09  6.553978e+09  6.627317e+09  6.695488e+09
# 140  6.320334e+09  6.399037e+09  6.476093e+09  6.549996e+09  6.618837e+09
# 156  5.706387e+09  5.768171e+09  5.827338e+09  5.882943e+09  5.933587e+09
# 102  4.753252e+09  4.794556e+09  4.832929e+09  4.867092e+09  4.895373e+09
# ..            ...           ...           ...           ...           ...
# 255  3.006000e+04  3.033500e+04  3.061000e+04  3.091000e+04  3.112200e+04
# 188  1.783700e+04  1.786400e+04  1.791600e+04  1.797200e+04  1.802400e+04
# 179  1.168200e+04  1.192400e+04  1.213200e+04  1.231500e+04  1.251100e+04
# 245  1.082800e+04  1.086500e+04  1.095600e+04  1.106900e+04  1.120400e+04
# 110           NaN           NaN           NaN           NaN           NaN
#
#              2022  2023
# 259  7.950947e+09   NaN
# 103  6.754030e+09   NaN
# 140  6.678280e+09   NaN
# 156  5.974552e+09   NaN
# 102  4.913887e+09   NaN
# ..            ...   ...
# 255  3.130500e+04   NaN
# 188  1.805500e+04   NaN
# 179  1.266800e+04   NaN
# 245  1.131200e+04   NaN
# 110           NaN   NaN
#
# [266 rows x 68 columns]

# %%
#TOP 5 COUNTRIES WITH THE HIGHEST POPULATON FOR 2022
total_highest_population=total_population_sort.head(5)
print("Top 5 countries with the highest populaion in 2022")
total_highest_population
# Out:
# Top 5 countries with the highest populaion in 2022
#             Country Name Country Code     Indicator Name Indicator Code  \
# 259                World          WLD  Population, total    SP.POP.TOTL
# 103     IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 140  Low & middle income          LMY  Population, total    SP.POP.TOTL
# 156        Middle income          MIC  Population, total    SP.POP.TOTL
# 102            IBRD only          IBD  Population, total    SP.POP.TOTL
#
#              1960          1961          1962          1963          1964  \
# 259  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
# 103  2.297972e+09  2.329504e+09  2.374276e+09  2.431314e+09  2.488809e+09
# 140  2.243179e+09  2.274050e+09  2.318173e+09  2.374537e+09  2.431355e+09
# 156  2.107416e+09  2.135116e+09  2.175940e+09  2.228877e+09  2.282094e+09
# 102  1.904347e+09  1.926043e+09  1.960606e+09  2.007061e+09  2.053555e+09
#
#              1965  ...          2014          2015          2016  \
# 259  3.328209e+09  ...  7.317040e+09  7.403850e+09  7.490415e+09
# 103  2.547220e+09  ...  6.160290e+09  6.240231e+09  6.319805e+09
# 140  2.489219e+09  ...  6.081161e+09  6.160876e+09  6.240319e+09
# 156  2.336193e+09  ...  5.513458e+09  5.578703e+09  5.642636e+09
# 102  2.100537e+09  ...  4.616585e+09  4.663653e+09  4.709004e+09
#
#              2017          2018          2019          2020          2021  \
# 259  7.576442e+09  7.660371e+09  7.741775e+09  7.820206e+09  7.888306e+09
# 103  6.399653e+09  6.477695e+09  6.553978e+09  6.627317e+09  6.695488e+09
# 140  6.320334e+09  6.399037e+09  6.476093e+09  6.549996e+09  6.618837e+09
# 156  5.706387e+09  5.768171e+09  5.827338e+09  5.882943e+09  5.933587e+09
# 102  4.753252e+09  4.794556e+09  4.832929e+09  4.867092e+09  4.895373e+09
#
#              2022  2023
# 259  7.950947e+09   NaN
# 103  6.754030e+09   NaN
# 140  6.678280e+09   NaN
# 156  5.974552e+09   NaN
# 102  4.913887e+09   NaN
#
# [5 rows x 68 columns]

# %%
#DATA VISUALIZATION
def add_value_labels(ax, spacing=10):
    for rect in ax.patches:
        x = rect.get_x() + rect.get_width() / 2
        y = rect.get_height() - 3
        va = 'bottom' if y > 0 else 'top'
        label = '{}'.format(y)
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(
            label,
            (x, y),
            xytext=(0, y_shift),
            textcoords='offset points',
            ha='center',
            va=va
        )

# %%
plt.figure(figsize=(20, 15))
plt.rcParams['axes.facecolor'] = 'white'

plt.subplot(2, 2, 1)
plot = sns.barplot(x="2022", y="Country Name", data=total_highest_population, palette="viridis")
plt.title("Top 10 Countries of Total Population (2022)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.subplot(2, 2, 2)
plot = sns.barplot(x="2000", y="Country Name", data=total_highest_population, palette="viridis")
plt.title("Top 10 Countries of Total Population in 2000")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-34-be7f0ead8f20>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x="2022", y="Country Name", data=total_highest_population, palette="viridis")
# <ipython-input-34-be7f0ead8f20>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x="2000", y="Country Name", data=total_highest_population, palette="viridis")

# %%
plt.figure(figsize=(20, 15))
plt.rcParams['axes.facecolor'] = 'white'

plt.subplot(2, 2, 1)
plot = sns.barplot(x='1999', y="Country Name", data=total_highest_population, palette="mako")
plt.title("Top Ten Countries of Total Population (1999)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.subplot(2, 2, 2)
plot = sns.barplot(x='1989', y="Country Name", data=total_highest_population, palette="mako")
plt.title("Top Ten Countries of Total Population (1989)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-78d9464e56f0>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x='1999', y="Country Name", data=total_highest_population, palette="mako")
# <ipython-input-35-78d9464e56f0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x='1989', y="Country Name", data=total_highest_population, palette="mako")

# %%
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="white"

plt.subplot(2,2,1)
plot=sns.lineplot(x='1960',y="Country Name", data=total_highest_population,palette="coolwarm")
plt.title("Top Ten countries Of Total Population 1960")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.lineplot(x='2022',y="Country Name",data=total_highest_population,palette="coolwarm")
plt.title("Top Ten countries Of Total Population 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-36-f34ca5bf34e1>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot=sns.lineplot(x='1960',y="Country Name", data=total_highest_population,palette="coolwarm")
# <ipython-input-36-f34ca5bf34e1>:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot=sns.lineplot(x='2022',y="Country Name",data=total_highest_population,palette="coolwarm")

# %%
#BOTTOM 10 COUNTRIES WITH THE HIGHEST POPULATION
total_population_sort_bt=total_population.sort_values(by='2022',ascending=True)
total_population_sort_bt
# Out:
#                  Country Name Country Code     Indicator Name Indicator Code  \
# 245                    Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                     Nauru          NRU  Population, total    SP.POP.TOTL
# 188                     Palau          PLW  Population, total    SP.POP.TOTL
# 255    British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147  St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# ..                        ...          ...                ...            ...
# 156             Middle income          MIC  Population, total    SP.POP.TOTL
# 140       Low & middle income          LMY  Population, total    SP.POP.TOTL
# 103          IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 259                     World          WLD  Population, total    SP.POP.TOTL
# 110            Not classified          INX  Population, total    SP.POP.TOTL
#
#              1960          1961          1962          1963          1964  \
# 245  5.404000e+03  5.436000e+03  5.471000e+03  5.503000e+03  5.525000e+03
# 179  4.582000e+03  4.753000e+03  4.950000e+03  5.198000e+03  5.484000e+03
# 188  9.446000e+03  9.639000e+03  9.851000e+03  1.007600e+04  1.031800e+04
# 255  7.850000e+03  7.885000e+03  7.902000e+03  7.919000e+03  7.949000e+03
# 147  4.135000e+03  4.258000e+03  4.388000e+03  4.524000e+03  4.666000e+03
# ..            ...           ...           ...           ...           ...
# 156  2.107416e+09  2.135116e+09  2.175940e+09  2.228877e+09  2.282094e+09
# 140  2.243179e+09  2.274050e+09  2.318173e+09  2.374537e+09  2.431355e+09
# 103  2.297972e+09  2.329504e+09  2.374276e+09  2.431314e+09  2.488809e+09
# 259  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
# 110           NaN           NaN           NaN           NaN           NaN
#
#              1965  ...          2014          2015          2016  \
# 245  5.548000e+03  ...  1.089900e+04  1.087700e+04  1.085200e+04
# 179  5.804000e+03  ...  1.094000e+04  1.118500e+04  1.143700e+04
# 188  1.056300e+04  ...  1.779600e+04  1.779400e+04  1.781600e+04
# 255  8.018000e+03  ...  2.897100e+04  2.936600e+04  2.973900e+04
# 147  4.832000e+03  ...  3.526100e+04  3.502000e+04  3.481100e+04
# ..            ...  ...           ...           ...           ...
# 156  2.336193e+09  ...  5.513458e+09  5.578703e+09  5.642636e+09
# 140  2.489219e+09  ...  6.081161e+09  6.160876e+09  6.240319e+09
# 103  2.547220e+09  ...  6.160290e+09  6.240231e+09  6.319805e+09
# 259  3.328209e+09  ...  7.317040e+09  7.403850e+09  7.490415e+09
# 110           NaN  ...           NaN           NaN           NaN
#
#              2017          2018          2019          2020          2021  \
# 245  1.082800e+04  1.086500e+04  1.095600e+04  1.106900e+04  1.120400e+04
# 179  1.168200e+04  1.192400e+04  1.213200e+04  1.231500e+04  1.251100e+04
# 188  1.783700e+04  1.786400e+04  1.791600e+04  1.797200e+04  1.802400e+04
# 255  3.006000e+04  3.033500e+04  3.061000e+04  3.091000e+04  3.112200e+04
# 147  3.449600e+04  3.385200e+04  3.312100e+04  3.255300e+04  3.194800e+04
# ..            ...           ...           ...           ...           ...
# 156  5.706387e+09  5.768171e+09  5.827338e+09  5.882943e+09  5.933587e+09
# 140  6.320334e+09  6.399037e+09  6.476093e+09  6.549996e+09  6.618837e+09
# 103  6.399653e+09  6.477695e+09  6.553978e+09  6.627317e+09  6.695488e+09
# 259  7.576442e+09  7.660371e+09  7.741775e+09  7.820206e+09  7.888306e+09
# 110           NaN           NaN           NaN           NaN           NaN
#
#              2022  2023
# 245  1.131200e+04   NaN
# 179  1.266800e+04   NaN
# 188  1.805500e+04   NaN
# 255  3.130500e+04   NaN
# 147  3.179100e+04   NaN
# ..            ...   ...
# 156  5.974552e+09   NaN
# 140  6.678280e+09   NaN
# 103  6.754030e+09   NaN
# 259  7.950947e+09   NaN
# 110           NaN   NaN
#
# [266 rows x 68 columns]

# %%
top_ten_bt_countries=total_population_sort_bt.head(10)
print("Top ten bottom Countries of Total Population:")
print(top_ten_bt_countries)
# Out:
# Top ten bottom Countries of Total Population:
#                  Country Name Country Code     Indicator Name Indicator Code  \
# 245                    Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                     Nauru          NRU  Population, total    SP.POP.TOTL
# 188                     Palau          PLW  Population, total    SP.POP.TOTL
# 255    British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147  St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# 84                  Gibraltar          GIB  Population, total    SP.POP.TOTL
# 212                San Marino          SMR  Population, total    SP.POP.TOTL
# 149                    Monaco          MCO  Population, total    SP.POP.TOTL
# 137             Liechtenstein          LIE  Population, total    SP.POP.TOTL
# 155          Marshall Islands          MHL  Population, total    SP.POP.TOTL
#
#         1960     1961     1962     1963     1964     1965  ...     2014  \
# 245   5404.0   5436.0   5471.0   5503.0   5525.0   5548.0  ...  10899.0
# 179   4582.0   4753.0   4950.0   5198.0   5484.0   5804.0  ...  10940.0
# 188   9446.0   9639.0   9851.0  10076.0  10318.0  10563.0  ...  17796.0
# 255   7850.0   7885.0   7902.0   7919.0   7949.0   8018.0  ...  28971.0
# 147   4135.0   4258.0   4388.0   4524.0   4666.0   4832.0  ...  35261.0
# 84   21822.0  21907.0  22249.0  22796.0  23347.0  23910.0  ...  32452.0
# 212  15556.0  15895.0  16242.0  16583.0  16926.0  17273.0  ...  33389.0
# 149  21797.0  21907.0  22106.0  22442.0  22766.0  23022.0  ...  36110.0
# 137  16472.0  16834.0  17221.0  17625.0  18058.0  18500.0  ...  37096.0
# 155  15374.0  15867.0  16387.0  16947.0  17537.0  18154.0  ...  50419.0
#
#         2015     2016     2017     2018     2019     2020     2021     2022  \
# 245  10877.0  10852.0  10828.0  10865.0  10956.0  11069.0  11204.0  11312.0
# 179  11185.0  11437.0  11682.0  11924.0  12132.0  12315.0  12511.0  12668.0
# 188  17794.0  17816.0  17837.0  17864.0  17916.0  17972.0  18024.0  18055.0
# 255  29366.0  29739.0  30060.0  30335.0  30610.0  30910.0  31122.0  31305.0
# 147  35020.0  34811.0  34496.0  33852.0  33121.0  32553.0  31948.0  31791.0
# 84   32520.0  32565.0  32602.0  32648.0  32685.0  32709.0  32669.0  32649.0
# 212  33570.0  33834.0  34056.0  34156.0  34178.0  34007.0  33745.0  33660.0
# 149  36760.0  37071.0  37044.0  37029.0  37034.0  36922.0  36686.0  36469.0
# 137  37355.0  37609.0  37889.0  38181.0  38482.0  38756.0  39039.0  39327.0
# 155  49410.0  48329.0  47187.0  45989.0  44728.0  43413.0  42050.0  41569.0
#
#      2023
# 245   NaN
# 179   NaN
# 188   NaN
# 255   NaN
# 147   NaN
# 84    NaN
# 212   NaN
# 149   NaN
# 137   NaN
# 155   NaN
#
# [10 rows x 68 columns]

# %%
#BOTTOM TEN COUNTRIES OF TOTAL POPULATION IN YEAR 2022 AND 2000
plt.figure(figsize=(20,15))
plt.rcParams['axes.facecolor']=="white"

plt.subplot(2,2,1)
plot=sns.scatterplot(x='2022',y="Country Name", data=top_ten_bt_countries,palette="coolwarm")
plt.title("Bottom Ten countries Of Total Population 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)
plt.subplot(2,2,2)

plot=sns.scatterplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Bottom countries Of Total Population 2000")
plt.xlabel("Total population")
plt.ylabel("country")

add_value_labels(plot)
plt.tight_layout()
# Out:
# <ipython-input-39-3af0d811e548>:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot=sns.scatterplot(x='2022',y="Country Name", data=top_ten_bt_countries,palette="coolwarm")
# <ipython-input-39-3af0d811e548>:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot=sns.scatterplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %%
#10 BOTTOM COUNTRIES OF TOTTAL POPULATION 1960
plt.figure(figsize=(20,15))
plt.rcParams['axes.facecolor']=="white"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name", data=top_ten_bt_countries,palette="coolwarm")
plt.title("Bottom Ten countries Of Total Population 1960")
plt.xlabel("Total population")
plt.ylabel("country")

add_value_labels(plot)
plt.tight_layout()
# Out:
# <ipython-input-43-5c1a1790a32d>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1960',y="Country Name", data=top_ten_bt_countries,palette="coolwarm")
